# %%
#INSTRUCCIONES
#Ingrese las ubicaciones HABITACION1/HABITACION2/HABITACION3 con letras mayusculas
#Ingrese el estado 0/1 respectivamente donde 0 significa encendido y 1 significa apagado

def foco_inteligente():
    # inicializamos estado_objetivo
    # 0 idica Encendido y 1 indica Apagando
    estado_objetivo = {'HABITACION1': '0', 'HABITACION2': '0', 'HABITACION3': '0'}
    costo = 0
    
    ingreso_ubicacion = input("Ingrese la ubicación del Foco Inteligente: ")# el usuario indica la ubicación del Foco Inteligente
    ingreso_estado = input("Ingrese el estado del: "+ingreso_ubicacion+ " ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
    
    
    if (ingreso_ubicacion  == 'HABITACION1'):
        #El usuario ingreso HABITACION1
        estado_ubicacion2 = input("Ingrese el estado de la HABITACIÓN 2 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        estado_ubicacion3 = input("Ingrese el estado de la HABITACIÓN 3 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        print("Meta Deseada:" + str(estado_objetivo)) #Se muestran los resultados deseados
    
        print("El Foco Inteligente se encuentra en la HABITACIÓN 1")# Se muestra la habitación en la que se encuentra el foco

        if(ingreso_estado == '1'):
            #El foco inteligente de la HABITACION1 se encuentra apagado
            print("El Foco Inteligente se encuentra apagado")
            #El foco inteligente se encendera
            estado_objetivo['HABITACION1'] ='0'
            costo += 1 #El costo aumentara cada que el foco se encienda
            print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 1")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 
                
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION2 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 2") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION2'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION3 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 3") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION3'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (ingreso_estado == '0'):
            #El Foco Inteligente de la Habitación 1 esta apagado
            print("El foco de la HABITACIÓN 1 se encuentra encendido")
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION2 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 2") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION2'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION3 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 3") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION3'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

        else:
            #El estado ingresado esta fuera del rango
            print("El estado ingresado no es valido")
                         
               
    elif (ingreso_ubicacion  == 'HABITACION2'):
        #El usuario ingreso HABITACION2
        estado_ubicacion2 = input("Ingrese el estado de la HABITACIÓN 1 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        estado_ubicacion3 = input("Ingrese el estado de la HABITACIÓN 3 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        print("Meta Deseada:" + str(estado_objetivo)) #Se muestran los resultados deseados
        
        print("El Foco Inteligente se encuentra en la HABITACIÓN 2")# Se muestra la habitación en la que se encuentra el foco

        if(ingreso_estado == '1'):
            #El foco inteligente de la HABITACION2 se encuentra apagado
            print("El Foco Inteligente se encuentra apagado")
            #El foco inteligente se encendera
            estado_objetivo['HABITACION2'] ='0'
            costo += 1 #El costo aumentara cada que el foco se encienda
            print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 2")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 
           
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION1 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 1") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION1'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
              
            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION3 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 3") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION3'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (ingreso_estado == '0'):
            print("El foco de la HABITACIÓN 2 se encuentra encendido")
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION1 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 1") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION1'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION3 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 3") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION3'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

                
        else:  
            #En caso de que el usuario ingrese un estado invalido
            print("El estado ingresado no es valido")
    
    #En caso de que el usuario ingrese como ubicación inicial la HABITACION3
    elif (ingreso_ubicacion  == 'HABITACION3'):
        #El usuario ingreso HABITACION3
        estado_ubicacion2 = input("Ingrese el estado de la HABITACIÓN 1 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        estado_ubicacion3 = input("Ingrese el estado de la HABITACIÓN 2 ")# el usuario indica la si el Foco Inteligente se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        print("Meta Deseada:" + str(estado_objetivo)) #Se muestran los resultados deseados
        
        print("El Foco Inteligente se encuentra en la HABITACIÓN 3")# Se muestra la habitación en la que se encuentra el foco

        if(ingreso_estado == '1'):
            #El foco inteligente de la HABITACION3 se encuentra apagado
            print("El Foco Inteligente se encuentra apagado")
            #El foco inteligente se encendera
            estado_objetivo['HABITACION3'] ='0'
            costo += 1 #El costo aumentara cada que el foco se encienda
            print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 
          
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION1 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 1") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION1'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
              
            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION2 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 2") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION2'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 2 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (ingreso_estado == '0'):
            print("El foco de la HABITACIÓN 3 se encuentra encendido")
            if(estado_ubicacion2 == '1'):
                #si el Foco Inteligente de la HABITACION1 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 1") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION1'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 1 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(estado_ubicacion3 == '1'):
                #si el Foco Inteligente de la HABITACION3 se encuentra apagado
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado")
                print("El Foco Inteligente es movido a la HABITACIÓN 3") 
                costo += 1 #Incrementa el costo por mover el Foco Inteligente
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #El foco inteligente se encendera
                estado_objetivo['HABITACION3'] ='0'
                costo += 1 #El costo aumentara cada que el foco inteligente se encienda
                print("El Foco Inteligente se esta encendiendo en la HABITACIÓN 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #El Foco Inteligente se encuentra encendido
                print("El Foco Inteligente de la HABITACIÓN 3 se encuentra encendido")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

        else:
            #En caso de que el estado ingresado sea erroneo
            print("El estado ingresado no es valido")
             
    else:
        #En caso de que se ingrese la ubicación erronea
        print("Ubicación erronea") 
        
    #Todo Encendido
    print("Estado Objetivo: " + str(estado_objetivo))
    print("Medición del desempeño " +str(costo))
        

foco_inteligente()
# Out:
# Ingrese la ubicación del Foco Inteligente: HABITACION1
# Ingrese el estado del: HABITACION1 1
# Ingrese el estado de la HABITACIÓN 2 1
# Ingrese el estado de la HABITACIÓN 3 1
# Meta Deseada:{'HABITACION1': '0', 'HABITACION2': '0', 'HABITACION3': '0'}
# El Foco Inteligente se encuentra en la HABITACIÓN 1
# El Foco Inteligente se encuentra apagado
# El Foco Inteligente se esta encendiendo en la HABITACIÓN 1
# El costo actual es: 1
# El Foco Inteligente de la HABITACIÓN 2 se encuentra apagado
# El Foco Inteligente es movido a la HABITACIÓN 2
# El costo actual es: 2
# El Foco Inteligente se esta encendiendo en la HABITACIÓN 2
# El costo actual es: 3
# El Foco Inteligente de la HABITACIÓN 3 se encuentra apagado
# El Foco Inteligente es movido a la HABITACIÓN 3
# El costo actual es: 4
# El Foco Inteligente se esta encendiendo en la HABITACIÓN 3
# El costo actual es: 5
# Estado Objetivo: {'HABITACION1': '0', 'HABITACION2': '0', 'HABITACION3': '0'}
# Medición del desempeño 5
